# %% [markdown]
# <a href="https://colab.research.google.com/github/anbubus/trabalho-metodos-matematicos-grupo10/blob/main/Q4_metmat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np

# %%
# Grafico de u(x,y)=0
def ReU(x):
  return (1+(x+1)**2)**(1/2)

x = np.linspace(-4,2,100)
y = ReU(x)

# %%
plt.figure(figsize = (12,6))
#plt.suptitle('Gráficos', fontsize=14, weight='bold', y=1.05)

plt.plot(x,y)
plt.plot(x,-y)
plt.title('Re(w)')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
# Out:
# Text(0, 0.5, 'Eixo y')

# %%
y2 = np.linspace(3,-3,100)


plt.show()


plt.plot(np.full(100,-1),y2)
plt.plot(x,np.zeros([100]))
plt.title('Im(w)')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')



plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go

# %%
def wU(x,y):
  return x**2 + 2*x + 2 - y**2
def wV(x,y):
  return 2*x*y + 2*y

Y = np.linspace(-2,2,100)
X = np.linspace(-4,2,100)

Y2=ReU(X)

Z = np.zeros([100,100])
Z2 = np.zeros([100,100])
Y3=np.full(100,-1)
for i in range(100):
   Z[i]= wU(X,Y[i])
   Z2[i]=wV(X,Y[i])

# %%
from sympy import *
x, y, z, U = symbols('x y z U')
U = x**(2)+2*x+2-y**(2)
U
# Out:
# x**2 + 2*x - y**2 + 2

# %%
from plotly.subplots import make_subplots

fig = go.Figure(data=[go.Surface(
    colorscale="jet",
    x = X,
    y = Y,
    z = Z, surfacecolor = Z2)])

fig.add_scatter3d(x=X.flatten(),y=Y2.flatten(), z=np.zeros([100]), mode='lines',line=dict(color='Black', width=6))
fig.add_scatter3d(x=X.flatten(),y=-Y2.flatten(), z=np.zeros([100]),mode='lines',line=dict(color='Black', width=6))
fig.add_scatter3d(x=Y3,y=Y.flatten(), z=np.zeros([100]),mode='lines',line=dict(color='#0000FF', width=6))
fig.add_scatter3d(x=X,y=np.zeros([100]), z=np.zeros([100]),mode='lines',line=dict(color='#0000FF', width=6))
fig.update_layout(title=f'U(x,y)={U}', showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
